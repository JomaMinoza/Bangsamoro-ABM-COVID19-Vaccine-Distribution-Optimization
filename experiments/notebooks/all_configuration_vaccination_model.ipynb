# %%
import os
import sys

import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../abm/'))
sys.path.insert(0, os.path.abspath('../simulation/'))
sys.path.insert(0, os.path.abspath('../mesa/'))

from mesa.batchrunner import BatchRunner

from simulation.grid.model import GridSimulationEnvironment

from abm.utils.collectors.total_susceptible import total_susceptible
from abm.utils.collectors.total_infected import total_infected
from abm.utils.collectors.total_deaths import total_deaths
from abm.utils.collectors.total_recovered import total_recovered
from abm.utils.collectors.total_vaccinated import total_vaccinated

from abm.utils.collectors.count_age_infected import *
from abm.utils.collectors.count_age_exposed import *
from abm.utils.collectors.count_age_died import *
from abm.utils.collectors.count_age_recovered import *

from abm.utils.collectors.count_peak_values import *

# %matplotlib inline

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
plt.style.use('ggplot')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

warnings.simplefilter('ignore')
# Out:
# /home/joma/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: DtypeWarning: Columns (10,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
default_scenario_model_params = {
    "height": 60,
    "width": 60,
    "incubation_period": 7,
    "recovery_period": 14,
    "transmission_rate":  0.01,
    "viral_load_probability":  0.01,
    "wearing_masks": 0.8,
    "social_distance_limit": 0.7,
    "natural_immunity": 0.2,
    "exercise": 0.3,
    "preexisting_conditions": 0.6,
    "minority_restrictions": 18,
    "adult_restrictions": 65,
    "scenarios": "No Vaccination",
    "vaccination_implementation": "After 0 Days",
    "scale": 1000,
}

default_vaccination_model_params = {
    "height": 60,
    "width": 60,
    "incubation_period": 7,
    "recovery_period": 14,
    "transmission_rate":  0.01,
    "viral_load_probability":  0.01,
    "wearing_masks": 0.8,
    "social_distance_limit": 0.7,
    "natural_immunity": 0.2,
    "exercise": 0.3,
    "preexisting_conditions": 0.6,
    "minority_restrictions": 18,
    "adult_restrictions": 65,
    "scenarios": "With Vaccination",
    "vaccination_implementation": "After 0 Days",
    "scale": 1000,
}

mobility_vaccination_model_params = default_vaccination_model_params

mobility_vaccination_model_params["mobile_workforce"] = True

elderly_vaccination_model_params = default_vaccination_model_params

elderly_vaccination_model_params["elderly"] = True

all_configuration_vaccination_model_params = default_vaccination_model_params
all_configuration_vaccination_model_params["mobile_workforce"] = True
all_configuration_vaccination_model_params["elderly"] = True

# %%
all_configuration_vaccination_model = GridSimulationEnvironment(**all_configuration_vaccination_model_params)
while all_configuration_vaccination_model.running and all_configuration_vaccination_model.schedule.steps < 270:
    all_configuration_vaccination_model.step()
# Out:
# Updating SCALE field...
# New Data: 1000
#
#
# Updating VACCINE_PRIORITIZATION field...
# New Data: {'frontliners_ratio': {'activated': 1, 'value': 0.001206896551724138}, 'public_admin': {'activated': 1, 'value': 0.06}, 'persons_with_difficulty': {'activated': 1, 'value': 0.03730271023}, 'gainful_workers': {'activated': 1, 'value': 0.47507927437}, 'mobile_workforce': {'activated': 1, 'value': 0.484}, 'elderly': {'activated': 1, 'value': 0.06693868492}}
#
#
# Updating MORTALITY_RATE field...
# New Data: {'age_00-09': {'min': 0, 'max': 9, 'rate': 0.004672897196261682}, 'age_10-19': {'min': 10, 'max': 19, 'rate': 0.0}, 'age_20-29': {'min': 20, 'max': 29, 'rate': 0.0006009615384615385}, 'age_30-39': {'min': 30, 'max': 39, 'rate': 0.004036326942482341}, 'age_40-49': {'min': 40, 'max': 49, 'rate': 0.009688934217236104}, 'age_50-59': {'min': 50, 'max': 59, 'rate': 0.017263427109974423}, 'age_60-69': {'min': 60, 'max': 69, 'rate': 0.03470919324577861}, 'age_70-79': {'min': 70, 'max': 79, 'rate': 0.08120649651972157}, 'age_80-up': {'min': 80, 'max': 100, 'rate': 0.09389671361502347}}
#
#
# Updating DISTRICT_DATA field...
# New Data: {'DISTRICT 1': {'susceptible': 0.9929901055686147, 'infected': 0.005813565480471908, 'recovered': 0.0010974587896809213, 'dead': 9.887016123251542e-05}, 'DISTRICT 2': {'susceptible': 0.9964367222150454, 'infected': 0.002689951771950222, 'recovered': 0.0008356478491151014, 'dead': 3.767816388924773e-05}, 'DISTRICT 3': {'susceptible': 0.9913420040086024, 'infected': 0.005986569718958934, 'recovered': 0.0025924246192559216, 'dead': 7.900165318274252e-05}, 'DISTRICT 4': {'susceptible': 0.9940024421710296, 'infected': 0.004836879371421421, 'recovered': 0.0010981140053762282, 'dead': 6.25644521727124e-05}, 'DISTRICT 5': {'susceptible': 0.9952516700286437, 'infected': 0.003829408559633388, 'recovered': 0.0008693884731727897, 'dead': 4.953293855011965e-05}, 'DISTRICT 6': {'susceptible': 0.9949554685457099, 'infected': 0.003466924809985852, 'recovered': 0.0015273864547490116, 'dead': 5.022018955523961e-05}}
#
#
# Updating POPULATION field...
# New Data: 3115
#
#
# Updating INFECTED field...
# New Data: 0.007477085419394593
#
#
# Updating RECOVERED field...
# New Data: 0.002423040386145986
#
#
# Updating DEAD field...
# New Data: 0.0002169503709979717
#
#
# Updating SUSCEPTIBLE field...
# New Data: 0.9898829238234614
#
#
# Updating VACCINE_DISTRIBUTION field...
# New Data: {'age_00-09': {'min': 0, 'max': 9, 'assign': 12.820749225719577}, 'age_10-19': {'min': 10, 'max': 19, 'assign': 72.97964943871145}, 'age_20-29': {'min': 20, 'max': 29, 'assign': 121.89573879222615}, 'age_30-39': {'min': 20, 'max': 29, 'assign': 140.43651459557447}, 'age_40-49': {'min': 30, 'max': 39, 'assign': 102.17150921419602}, 'age_50-59': {'min': 40, 'max': 49, 'assign': 60.75062710033278}, 'age_60-69': {'min': 50, 'max': 59, 'assign': 28.20564829658307}, 'age_70-79': {'min': 60, 'max': 69, 'assign': 6.903480352310542}, 'age_80-up': {'min': 70, 'max': 79, 'assign': 0.7889691831212049}}
#
#
# Updating VACCINE_DISTRIBUTION_LOCATION field...
# New Data: {'LOCATIONS': [{'LOCATION': 1, 'ALLOCATION': {'0-9': 2.13679153761993, '10-19': 12.163274906451909, '20-29': 20.315956465371027, '30-39': 23.406085765929074, '40-49': 17.028584869032674, '50-59': 10.12510451672213, '60-69': 4.700941382763845, '70-79': 1.1505800587184238, '80+': 0.13149486385353415}}, {'LOCATION': 2, 'ALLOCATION': {'0-9': 2.1367915376199296, '10-19': 12.163274906451907, '20-29': 20.31595646537102, '30-39': 23.406085765929074, '40-49': 17.02858486903267, '50-59': 10.125104516722129, '60-69': 4.700941382763845, '70-79': 1.1505800587184236, '80+': 0.1314948638535341}}, {'LOCATION': 3, 'ALLOCATION': {'0-9': 2.13679153761993, '10-19': 12.163274906451909, '20-29': 20.315956465371023, '30-39': 23.406085765929078, '40-49': 17.02858486903267, '50-59': 10.125104516722129, '60-69': 4.700941382763846, '70-79': 1.1505800587184236, '80+': 0.13149486385353415}}, {'LOCATION': 4, 'ALLOCATION': {'0-9': 2.13679153761993, '10-19': 12.163274906451909, '20-29': 20.315956465371023, '30-39': 23.406085765929078, '40-49': 17.02858486903267, '50-59': 10.125104516722129, '60-69': 4.700941382763845, '70-79': 1.1505800587184236, '80+': 0.13149486385353415}}, {'LOCATION': 5, 'ALLOCATION': {'0-9': 2.13679153761993, '10-19': 12.163274906451909, '20-29': 20.315956465371027, '30-39': 23.406085765929078, '40-49': 17.02858486903267, '50-59': 10.125104516722129, '60-69': 4.700941382763846, '70-79': 1.1505800587184238, '80+': 0.13149486385353415}}, {'LOCATION': 6, 'ALLOCATION': {'0-9': 2.13679153761993, '10-19': 12.163274906451907, '20-29': 20.315956465371023, '30-39': 23.406085765929074, '40-49': 17.02858486903267, '50-59': 10.125104516722129, '60-69': 4.700941382763845, '70-79': 1.1505800587184236, '80+': 0.13149486385353415}}]}
#
#
# Updating POPULATION_DISTRIBUTION field...
# New Data: {'age_00-09': {'min': 0, 'max': 9, 'value': 45}, 'age_10-19': {'min': 10, 'max': 19, 'value': 372}, 'age_20-29': {'min': 20, 'max': 29, 'value': 666}, 'age_30-39': {'min': 30, 'max': 39, 'value': 656}, 'age_40-49': {'min': 40, 'max': 49, 'value': 530}, 'age_50-59': {'min': 50, 'max': 59, 'value': 336}, 'age_60-69': {'min': 60, 'max': 69, 'value': 121}, 'age_70-79': {'min': 70, 'max': 79, 'value': 36}, 'age_80-up': {'min': 80, 'max': 100, 'value': 5}}
#
#
# Updating VACCINE_DISTRIBUTION field...
# New Data: {'age_00-09': {'min': 0, 'max': 9, 'assign': 8.808727529171637}, 'age_10-19': {'min': 10, 'max': 19, 'assign': 72.81881424115221}, 'age_20-29': {'min': 20, 'max': 29, 'assign': 130.36916743174027}, 'age_30-39': {'min': 20, 'max': 29, 'assign': 128.41167242525765}, 'age_40-49': {'min': 30, 'max': 39, 'assign': 103.74723534357707}, 'age_50-59': {'min': 40, 'max': 49, 'assign': 65.7718322178149}, 'age_60-69': {'min': 50, 'max': 59, 'assign': 23.685689578439295}, 'age_70-79': {'min': 60, 'max': 69, 'assign': 7.046982023337311}, 'age_80-up': {'min': 70, 'max': 79, 'assign': 0.9787475032412931}}
#
#
# Updating VACCINE_DISTRIBUTION_LOCATION field...
# New Data: {'LOCATIONS': [{'LOCATION': 1, 'ALLOCATION': {'0-9': 1.4681212548619393, '10-19': 12.136469040192035, '20-29': 21.728194571956706, '30-39': 21.401945404209606, '40-49': 17.291205890596178, '50-59': 10.961972036302482, '60-69': 3.947614929739882, '70-79': 1.1744970038895517, '80+': 0.16312458387354883}}, {'LOCATION': 2, 'ALLOCATION': {'0-9': 1.46812125486194, '10-19': 12.136469040192038, '20-29': 21.728194571956713, '30-39': 21.401945404209613, '40-49': 17.29120589059618, '50-59': 10.961972036302484, '60-69': 3.9476149297398826, '70-79': 1.174497003889552, '80+': 0.16312458387354886}}, {'LOCATION': 3, 'ALLOCATION': {'0-9': 1.4681212548619398, '10-19': 12.136469040192035, '20-29': 21.728194571956706, '30-39': 21.40194540420961, '40-49': 17.291205890596178, '50-59': 10.961972036302484, '60-69': 3.947614929739882, '70-79': 1.1744970038895517, '80+': 0.16312458387354883}}, {'LOCATION': 4, 'ALLOCATION': {'0-9': 1.4681212548619398, '10-19': 12.136469040192035, '20-29': 21.72819457195671, '30-39': 21.40194540420961, '40-49': 17.29120589059618, '50-59': 10.961972036302484, '60-69': 3.9476149297398826, '70-79': 1.174497003889552, '80+': 0.16312458387354886}}, {'LOCATION': 5, 'ALLOCATION': {'0-9': 1.4681212548619393, '10-19': 12.136469040192033, '20-29': 21.728194571956703, '30-39': 21.401945404209606, '40-49': 17.291205890596178, '50-59': 10.961972036302482, '60-69': 3.9476149297398826, '70-79': 1.1744970038895517, '80+': 0.16312458387354886}}, {'LOCATION': 6, 'ALLOCATION': {'0-9': 1.4681212548619398, '10-19': 12.136469040192033, '20-29': 21.728194571956706, '30-39': 21.401945404209606, '40-49': 17.291205890596178, '50-59': 10.961972036302482, '60-69': 3.947614929739882, '70-79': 1.1744970038895517, '80+': 0.16312458387354886}}]}

# %%
agents_infected_collector = all_configuration_vaccination_model.agents_infected_collector.get_model_vars_dataframe()
agents_infected_collector.to_csv("all_configuration_vaccination_model.agents_infected_collector.csv")
agents_infected_collector.plot.line()

# %%
agents_exposed_collector = all_configuration_vaccination_model.agents_exposed_collector.get_model_vars_dataframe()
agents_exposed_collector.to_csv("all_configuration_vaccination_model.agents_exposed_collector.csv")
agents_exposed_collector.plot.line()

# %%
agents_died_collector = all_configuration_vaccination_model.agents_died_collector.get_model_vars_dataframe()
agents_died_collector.to_csv("all_configuration_vaccination_model.agents_died_collector.csv")
agents_died_collector.plot.line()

# %%
agents_recovered_collector = all_configuration_vaccination_model.agents_recovered_collector.get_model_vars_dataframe()
agents_recovered_collector.to_csv("all_configuration_vaccination_model.agents_recovered_collector.csv")
agents_recovered_collector.plot.line()

# %%
model_peak_collector = all_configuration_vaccination_model.model_peak_collector.get_model_vars_dataframe()
model_peak_collector.to_csv("all_configuration_vaccination_model.model_peak_collector.csv")
model_peak_collector.head()
# Out:
#    Peak Infected  Peak Date
# 0             23         23
# 1             24         24
# 2             32         32
# 3             41         41
# 4             53         53

# %%
model_agents = all_configuration_vaccination_model.datacollector.get_model_vars_dataframe()
model_agents.to_csv("all_configuration_vaccination_model.model_agents.csv")
model_agents.head()
# Out:
#    Susceptible  Infected  Deaths  Recovered  Vaccinated
# 0         2547        23       3          7         536
# 1         2547        23       3          7         536
# 2         2537        24       3          7         536
# 3         2519        32       3          7         536
# 4         2505        41       3          7         536
