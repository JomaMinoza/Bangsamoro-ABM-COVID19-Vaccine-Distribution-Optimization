# %%
import os
import sys

import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../abm/'))
sys.path.insert(0, os.path.abspath('../simulation/'))
sys.path.insert(0, os.path.abspath('../mesa/'))

# %matplotlib inline

plt.style.use('ggplot')

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

warnings.simplefilter('ignore')

# %%
df1 = pd.read_csv("iterations/1/mobility_vaccination_model.agents_infected_collector.csv", index_col = 0)
df1
# Out:
#      0-9  10-19  20-29  30-39  40-49  50-59  60-69  70-79  80+
# 0      3      0      7      4      2      2      2      0    0
# 1      3      0      7      4      2      2      2      0    0
# 2      3      0      7      4      2      2      2      0    0
# 3      3      0     10      7      7      2      2      0    0
# 4      3      0     12      9     11      2      3      0    0
# 5      3      0     15     11     12      5      4      0    0
# 6      3      0     15     15     17      6      4      0    0
# 7      3      1     17     15     16      8      5      0    0
# 8      2      1     18     18     17      9      5      0    0
# 9      2      1     18     22     14      9      4      0    0
# 10     2      1     18     17     12     11      3      0    0
# 11     2      2     18     16     11     10      3      0    0
# 12     2      2     18     15     12     10      3      0    0
# 13     1      1     16     17     12     12      1      0    0
# ...

# %%
data = []

for i in range(1,11):
    df = pd.read_csv("iterations/%d/elderly_vaccination_model.agents_infected_collector.csv"%(i), index_col = 0)
    data.append(df)

# %%
ave_df = data[0].copy()

# %%
for index, row in ave_df.iterrows():
    ave_df.at[index,"0-9"] = np.mean([data[i]["0-9"][index] for i in range(0,10)])
    ave_df.at[index,"10-19"] = np.mean([data[i]["10-19"][index] for i in range(0,10)])
    ave_df.at[index,"20-29"] = np.mean([data[i]["20-29"][index] for i in range(0,10)])
    ave_df.at[index,"30-39"] = np.mean([data[i]["30-39"][index] for i in range(0,10)])
    ave_df.at[index,"40-49"] = np.mean([data[i]["40-49"][index] for i in range(0,10)])
    ave_df.at[index,"50-59"] = np.mean([data[i]["50-59"][index] for i in range(0,10)])
    ave_df.at[index,"60-69"] = np.mean([data[i]["60-69"][index] for i in range(0,10)])
    ave_df.at[index,"70-79"] = np.mean([data[i]["70-79"][index] for i in range(0,10)])
    ave_df.at[index,"80+"]   = np.mean([data[i]["80+"][index] for i in range(0,10)])

# %%
ave_df.plot.line()
plt.savefig('agents_infected_collector.elderly_vaccination_model_params.png')

# %%
models = ["default_scenario_model", "default_vaccination_model", "mobility_vaccination_model", "elderly_vaccination_model", "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("iterations/%d/%s.agents_infected_collector.csv"%(i,model), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"0-9"] = np.mean([data[i]["0-9"][index] for i in range(0,10)])
        ave_df.at[index,"10-19"] = np.mean([data[i]["10-19"][index] for i in range(0,10)])
        ave_df.at[index,"20-29"] = np.mean([data[i]["20-29"][index] for i in range(0,10)])
        ave_df.at[index,"30-39"] = np.mean([data[i]["30-39"][index] for i in range(0,10)])
        ave_df.at[index,"40-49"] = np.mean([data[i]["40-49"][index] for i in range(0,10)])
        ave_df.at[index,"50-59"] = np.mean([data[i]["50-59"][index] for i in range(0,10)])
        ave_df.at[index,"60-69"] = np.mean([data[i]["60-69"][index] for i in range(0,10)])
        ave_df.at[index,"70-79"] = np.mean([data[i]["70-79"][index] for i in range(0,10)])
        ave_df.at[index,"80+"]   = np.mean([data[i]["80+"][index] for i in range(0,10)])
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    plt.savefig('agents_infected_collector.%s.png'%(model))

# %%
models = ["default_scenario_model", "default_vaccination_model", "mobility_vaccination_model", "elderly_vaccination_model", "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("iterations/%d/%s.agents_exposed_collector.csv"%(i,model), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"0-9"] = np.mean([data[i]["0-9"][index] for i in range(0,10)])
        ave_df.at[index,"10-19"] = np.mean([data[i]["10-19"][index] for i in range(0,10)])
        ave_df.at[index,"20-29"] = np.mean([data[i]["20-29"][index] for i in range(0,10)])
        ave_df.at[index,"30-39"] = np.mean([data[i]["30-39"][index] for i in range(0,10)])
        ave_df.at[index,"40-49"] = np.mean([data[i]["40-49"][index] for i in range(0,10)])
        ave_df.at[index,"50-59"] = np.mean([data[i]["50-59"][index] for i in range(0,10)])
        ave_df.at[index,"60-69"] = np.mean([data[i]["60-69"][index] for i in range(0,10)])
        ave_df.at[index,"70-79"] = np.mean([data[i]["70-79"][index] for i in range(0,10)])
        ave_df.at[index,"80+"]   = np.mean([data[i]["80+"][index] for i in range(0,10)])
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    plt.savefig('agents_exposed_collector.%s.png'%(model))

# %%
models = ["default_scenario_model", "default_vaccination_model", "mobility_vaccination_model", "elderly_vaccination_model", "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("iterations/%d/%s.agents_died_collector.csv"%(i,model), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"0-9"] = np.mean([data[i]["0-9"][index] for i in range(0,10)])
        ave_df.at[index,"10-19"] = np.mean([data[i]["10-19"][index] for i in range(0,10)])
        ave_df.at[index,"20-29"] = np.mean([data[i]["20-29"][index] for i in range(0,10)])
        ave_df.at[index,"30-39"] = np.mean([data[i]["30-39"][index] for i in range(0,10)])
        ave_df.at[index,"40-49"] = np.mean([data[i]["40-49"][index] for i in range(0,10)])
        ave_df.at[index,"50-59"] = np.mean([data[i]["50-59"][index] for i in range(0,10)])
        ave_df.at[index,"60-69"] = np.mean([data[i]["60-69"][index] for i in range(0,10)])
        ave_df.at[index,"70-79"] = np.mean([data[i]["70-79"][index] for i in range(0,10)])
        ave_df.at[index,"80+"]   = np.mean([data[i]["80+"][index] for i in range(0,10)])
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    plt.savefig('agents_died_collector.%s.png'%(model))

# %%
models = ["default_scenario_model", "default_vaccination_model", "mobility_vaccination_model", "elderly_vaccination_model", "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("iterations/%d/%s.agents_recovered_collector.csv"%(i,model), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"0-9"] = np.mean([data[i]["0-9"][index] for i in range(0,10)])
        ave_df.at[index,"10-19"] = np.mean([data[i]["10-19"][index] for i in range(0,10)])
        ave_df.at[index,"20-29"] = np.mean([data[i]["20-29"][index] for i in range(0,10)])
        ave_df.at[index,"30-39"] = np.mean([data[i]["30-39"][index] for i in range(0,10)])
        ave_df.at[index,"40-49"] = np.mean([data[i]["40-49"][index] for i in range(0,10)])
        ave_df.at[index,"50-59"] = np.mean([data[i]["50-59"][index] for i in range(0,10)])
        ave_df.at[index,"60-69"] = np.mean([data[i]["60-69"][index] for i in range(0,10)])
        ave_df.at[index,"70-79"] = np.mean([data[i]["70-79"][index] for i in range(0,10)])
        ave_df.at[index,"80+"]   = np.mean([data[i]["80+"][index] for i in range(0,10)])
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    plt.savefig('agents_recovered_collector.%s.png'%(model))

# %%
models = ["default_scenario_model", "default_vaccination_model", "mobility_vaccination_model", "elderly_vaccination_model", "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("iterations/%d/%s.model_agents.csv"%(i,model), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"Susceptible"] = np.mean([data[i]["Susceptible"][index] for i in range(0,10)])
        ave_df.at[index,"Infected"] = np.mean([data[i]["Infected"][index] for i in range(0,10)])
        ave_df.at[index,"Recovered"] = np.mean([data[i]["Recovered"][index] for i in range(0,10)])
        ave_df.at[index,"Deaths"] = np.mean([data[i]["Deaths"][index] for i in range(0,10)])
        ave_df.at[index,"Vaccinated"] = np.mean([data[i]["Vaccinated"][index] for i in range(0,10)])
    print(model)
    print(ave_df.tail(1))
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    plt.savefig('model_agents.%s.png'%(model))
# Out:
# default_scenario_model
#      Susceptible  Infected  Deaths  Recovered  Vaccinated
# 270         2738        58     143        154           0
# default_vaccination_model
#      Susceptible  Infected  Deaths  Recovered  Vaccinated
# 270         2257        48     123        131         538
# mobility_vaccination_model
#      Susceptible  Infected  Deaths  Recovered  Vaccinated
# 270         2249        44     131        133         540
# elderly_vaccination_model
#      Susceptible  Infected  Deaths  Recovered  Vaccinated
# 270         2237        47     137        137         540
# all_configuration_vaccination_model
#      Susceptible  Infected  Deaths  Recovered  Vaccinated
# 270         2248        48     130        136         538

# %%
default_scenario_model
     Susceptible  Infected  Deaths  Recovered  Vaccinated
270         2738        58     143        154           0
default_vaccination_model
     Susceptible  Infected  Deaths  Recovered  Vaccinated
270         2257        48     123        131         538
mobility_vaccination_model
     Susceptible  Infected  Deaths  Recovered  Vaccinated
270         2249        44     131        133         540
elderly_vaccination_model
     Susceptible  Infected  Deaths  Recovered  Vaccinated
270         2237        47     137        137         540
all_configuration_vaccination_model
     Susceptible  Infected  Deaths  Recovered  Vaccinated
270         2248        48     130        136         538

# %%
base = 58
default_vaccination_model = 1 - 48/58
mobility_vaccination_model = 1 - 44/58
elderly_vaccination_model = 1 - 47/58
all_configuration_vaccination_model = 1 - 48/58
print(default_vaccination_model, mobility_vaccination_model, elderly_vaccination_model, all_configuration_vaccination_model)
# Out:
# 0.1724137931034483 0.24137931034482762 0.18965517241379315 0.1724137931034483

# %%
base = 154
default_vaccination_model = (538 + 131)/base
mobility_vaccination_model = (538 + 133)/base
elderly_vaccination_model = (538 + 137)/base
all_configuration_vaccination_model = (538 + 136)/base
print(default_vaccination_model, mobility_vaccination_model, elderly_vaccination_model, all_configuration_vaccination_model)
# Out:
# 4.3441558441558445 4.357142857142857 4.383116883116883 4.376623376623376
