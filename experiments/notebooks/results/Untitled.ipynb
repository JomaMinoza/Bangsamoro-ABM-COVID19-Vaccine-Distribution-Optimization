# %%
import os
import sys

import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.insert(0, os.getcwd() + '/../../')
sys.path.insert(0, os.getcwd() + '/../../abm/')
sys.path.insert(0, os.getcwd() + '/../../simulation/')
sys.path.insert(0, os.getcwd() + '/../../mesa/')

# %matplotlib inline

plt.style.use('ggplot')

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

warnings.simplefilter('ignore')

# %%
models = ["default_scenario_model",
          "mobility_vaccination_model",
          "elderly_vaccination_model",
          "social_vaccination_model",
         "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(1,11):
        df = pd.read_csv("{0}/agents_summary/{1}.csv".format(model, i), index_col = 0)
        data.append(df.head(100))
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"Susceptible"] = np.mean([data[i]["Susceptible"][index] for i in range(0,10)])
        ave_df.at[index,"Infected"] = np.mean([data[i]["Infected"][index] for i in range(0,10)])
        ave_df.at[index,"Recovered"] = np.mean([data[i]["Recovered"][index] for i in range(0,10)])
        ave_df.at[index,"Deaths"] = np.mean([data[i]["Deaths"][index] for i in range(0,10)])
        ave_df.at[index,"Vaccinated"] = np.mean([data[i]["Vaccinated"][index] for i in range(0,10)])
    print(model)
    print(ave_df.tail(1))
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    #plt.savefig('agents_infected_collector.%s.png'%(model))
# Out:
# default_scenario_model
#     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 99         4330       59        25     453       3811           0
# mobility_vaccination_model
#     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 99         2694       46        25     159       2624        3116
# elderly_vaccination_model
#     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 99         2754       60        25     173       2671        2996
# social_vaccination_model
#     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 99         2714       60        25     167       2621        3095
# all_configuration_vaccination_model
#     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 99         2634       49        25     164       2593        3205

# %%
models = ["default_scenario_model",
          "mobility_vaccination_model",
          "elderly_vaccination_model",
          "social_vaccination_model",
         "all_configuration_vaccination_model"]

for i, model in enumerate(models):
    data = []
    for i in range(0,20):
        df = pd.read_csv("{0}/agents_summary/{1}.csv".format(model, i), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"Susceptible"] = np.mean([data[i]["Susceptible"][index] for i in range(0,10)])
        ave_df.at[index,"Infected"] = np.mean([data[i]["Infected"][index] for i in range(0,10)])
        ave_df.at[index,"Recovered"] = np.mean([data[i]["Recovered"][index] for i in range(0,10)])
        ave_df.at[index,"Deaths"] = np.mean([data[i]["Deaths"][index] for i in range(0,10)])
        ave_df.at[index,"Vaccinated"] = np.mean([data[i]["Vaccinated"][index] for i in range(0,10)])
    print(model)
    print(ave_df.tail(1))
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    #plt.savefig('agents_infected_collector.%s.png'%(model))
# Out:
# default_scenario_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         4308        1         8     450       3906           0
# mobility_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2673        1         8     160       2719        3113
# elderly_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2733        2         8     174       2771        2986
# social_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2681        0         8     169       2714        3100
# all_configuration_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2619        1         8     165       2691        3191

# %%
print(np.array([8,450,3906])/np.sum([8,450,3906]))
print(np.array([8,160,2719])/np.sum([8,160,2719]))
print(np.array([8,174,2771])/np.sum([8,174,2771]))
print(np.array([8,169,2714])/np.sum([8,169,2714]))
print(np.array([8,165,2691])/np.sum([8,165,2691]))
# Out:
# [0.00183318 0.10311641 0.89505041]
# [0.00277104 0.05542085 0.94180811]
# [0.00270911 0.05892313 0.93836776]
# [0.00276721 0.05845728 0.93877551]
# [0.0027933  0.05761173 0.93959497]

# %%
models = ["default_vaccination_model",
          "default_vaccination_model_25_hesistancy",
          "default_vaccination_model_50_hesistancy",
          "default_vaccination_model_75_hesistancy",
         "default_vaccination_model_100_hesistancy"]

for i, model in enumerate(models):
    data = []
    for i in range(0,20):
        df = pd.read_csv("{0}/agents_summary/{1}.csv".format(model, i), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"Susceptible"] = np.mean([data[i]["Susceptible"][index] for i in range(0,10)])
        ave_df.at[index,"Infected"] = np.mean([data[i]["Infected"][index] for i in range(0,10)])
        ave_df.at[index,"Recovered"] = np.mean([data[i]["Recovered"][index] for i in range(0,10)])
        ave_df.at[index,"Deaths"] = np.mean([data[i]["Deaths"][index] for i in range(0,10)])
        ave_df.at[index,"Vaccinated"] = np.mean([data[i]["Vaccinated"][index] for i in range(0,10)])
        
    print(model)
    print(ave_df.tail(1))
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    #plt.savefig('agents_infected_collector.%s.png'%(model))
# Out:
# default_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2718        2         8     172       2749        3025
# default_vaccination_model_25_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3172        1         8     262       3103        2127
# default_vaccination_model_50_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3511        2         8     312       3311        1531
# default_vaccination_model_75_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3923        0         8     388       3604         750
# default_vaccination_model_100_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         4335        1         8     447       3882           0

# %%
print(np.array([8,172,2749])/np.sum([8,172,2749]))
print(np.array([8,262,3103])/np.sum([8,262,3103]))
print(np.array([8,312,3311])/np.sum([8,312,3311]))
print(np.array([8,388,3604])/np.sum([8,388,3604]))
print(np.array([8,447,3882])/np.sum([8,447,3882]))
# Out:
# [0.00273131 0.05872311 0.93854558]
# [0.00237178 0.07767566 0.91995256]
# [0.00220325 0.08592674 0.91187001]
# [0.002 0.097 0.901]
# [0.00184459 0.10306664 0.89508877]

# %%
models = ["all_configuration_vaccination_model",
          "all_configuration_vaccination_model_25_hesistancy",
          "all_configuration_vaccination_model_50_hesistancy",
          "all_configuration_vaccination_model_75_hesistancy",
         "all_configuration_vaccination_model_100_hesistancy"]

for i, model in enumerate(models):
    data = []
    for i in range(0,20):
        df = pd.read_csv("{0}/agents_summary/{1}.csv".format(model, i), index_col = 0)
        data.append(df)
        
    ave_df = data[0].copy()
    
    for index, row in ave_df.iterrows():
        ave_df.at[index,"Susceptible"] = np.mean([data[i]["Susceptible"][index] for i in range(0,10)])
        ave_df.at[index,"Infected"] = np.mean([data[i]["Infected"][index] for i in range(0,10)])
        ave_df.at[index,"Recovered"] = np.mean([data[i]["Recovered"][index] for i in range(0,10)])
        ave_df.at[index,"Deaths"] = np.mean([data[i]["Deaths"][index] for i in range(0,10)])
        ave_df.at[index,"Vaccinated"] = np.mean([data[i]["Vaccinated"][index] for i in range(0,10)])
    print(model)
    print(ave_df.tail(1))
        
    ave_df.plot.line(color=['b', 'g', 'r', 'c', 'm', 'y', 'k','gold', "orange"])
    #plt.savefig('agents_infected_collector.%s.png'%(model))
# Out:
# all_configuration_vaccination_model
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         2619        1         8     165       2691        3191
# all_configuration_vaccination_model_25_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3048        0         8     229       3011        2377
# all_configuration_vaccination_model_50_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3488        1         8     310       3263        1603
# all_configuration_vaccination_model_75_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         3880        0         8     383       3573         828
# all_configuration_vaccination_model_100_hesistancy
#      Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
# 240         4294        1         8     453       3918           0

# %%
default_scenario_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
240         4306        3         8     454       3904           0
mobility_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
240         2665        3         8     159       2724        3116
elderly_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
240         2722        1         8     173       2774        2996
social_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
240         2685        0         8     167       2717        3095
all_configuration_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
240         2606        1         8     164       2691        3205


    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
119         4321       31        19     453       3850           0
mobility_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
119         2681       36        19     159       2664        3116
elderly_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
119         2737       36        19     173       2713        2996
social_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
119         2701       33        20     167       2661        3095
all_configuration_vaccination_model
     Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
119         2621       28        16     164       2637        3205



default_scenario_model
    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
99         4330       59        25     453       3811           0
mobility_vaccination_model
    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
99         2694       46        25     159       2624        3116
elderly_vaccination_model
    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
99         2754       60        25     173       2671        2996
social_vaccination_model
    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
99         2714       60        25     167       2621        3095
all_configuration_vaccination_model
    Susceptible  Exposed  Infected  Deaths  Recovered  Vaccinated
99         2634       49        25     164       2593        3205
